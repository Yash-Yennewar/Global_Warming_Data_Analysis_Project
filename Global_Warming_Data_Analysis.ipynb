# %%
# Global Warming Data Analysis

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# <div style="background-color: #36afaa; padding: 15px; border-radius: 10px; font-size: 20px; font-weight: 10px">
#   <h1 style="color: #f2f4f4ff; text-align: center; font-family: times new roman;"><strong>Global Warming Data</strong></h1>
# </div>

# %%
df = pd.read_csv("D:\\Jason\\Python\\Global_Warming_Data_Analysis\\global_warming_dataset.csv")
df
# Out:
#            Country  Year  Temperature_Anomaly  CO2_Emissions    Population  \
# 0      Country_103  1913            -1.163537   8.876061e+08  1.627978e+08
# 1      Country_180  1950            -0.432122   4.497517e+08  4.281359e+08
# 2       Country_93  2014             0.444954   4.579080e+08  4.926732e+08
# 3       Country_15  2020            -1.171616   5.049503e+08  1.252169e+09
# 4      Country_107  1964            -0.564038   6.898891e+08  2.932960e+08
# ...            ...   ...                  ...            ...           ...
# 99995  Country_137  1950            -1.375490   4.992342e+08  1.367949e+09
# 99996   Country_42  1921             1.276176   5.846066e+08  1.010792e+09
# 99997   Country_53  1971             1.195518   5.892516e+08  1.466795e+09
# 99998   Country_60  1940            -0.344281   5.008876e+08  4.591192e+07
# 99999  Country_106  1936             0.306962   5.675235e+08  1.088954e+09
#
# ...

# %% [markdown]
# <div style="background-color: #aaaaaa; padding: 15px; border-radius: 10px; font-size: 20px; font-weight: 10px">
#   <h1 style="color: #000019; text-align: center; font-family: times new roman;"><strong>Exploring Global Warming Dataset</strong></h1>
# </div>

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100000 entries, 0 to 99999
# Data columns (total 26 columns):
#  #   Column                         Non-Null Count   Dtype
# ---  ------                         --------------   -----
#  0   Country                        100000 non-null  object
#  1   Year                           100000 non-null  int64
#  2   Temperature_Anomaly            100000 non-null  float64
#  3   CO2_Emissions                  100000 non-null  float64
#  4   Population                     100000 non-null  float64
#  5   Forest_Area                    100000 non-null  float64
#  6   GDP                            100000 non-null  float64
#  7   Renewable_Energy_Usage         100000 non-null  float64
#  8   Methane_Emissions              100000 non-null  float64
#  9   Sea_Level_Rise                 100000 non-null  float64
#  10  Arctic_Ice_Extent              100000 non-null  float64
#  11  Urbanization                   100000 non-null  float64
# ...

# %%
df.describe()
# Out:
#                 Year  Temperature_Anomaly  CO2_Emissions    Population  \
# count  100000.000000        100000.000000   1.000000e+05  1.000000e+05
# mean     1961.422100             0.002647   5.007007e+08  7.501973e+08
# std        35.758799             1.154579   2.887388e+08  4.328709e+08
# min      1900.000000            -1.999981   1.022271e+05  1.013054e+06
# 25%      1930.000000            -0.999449   2.504223e+08  3.762545e+08
# 50%      1961.000000             0.003523   5.006769e+08  7.499212e+08
# 75%      1992.000000             0.998067   7.506318e+08  1.125222e+09
# max      2023.000000             1.999958   9.999793e+08  1.499992e+09
#
#          Forest_Area           GDP  Renewable_Energy_Usage  Methane_Emissions  \
# count  100000.000000  1.000000e+05           100000.000000       1.000000e+05
# mean       50.012410  4.995923e+12               50.115658       5.003713e+06
# std        28.806287  2.883117e+12               28.841490       2.887606e+06
# ...

# %%
df.shape
# Out:
# (100000, 26)

# %% [markdown]
# <div style="background-color: #36afaa; padding: 15px; border-radius: 10px; font-size: 20px; font-weight: 10px">
#   <h1 style="color: #f2f4f4ff; text-align: center; font-family: times new roman;"><strong>Exploring for Required Data</strong></h1>
# </div>

# %%
df = df.loc[:,["Country","Year","Temperature_Anomaly","CO2_Emissions","Population","Methane_Emissions","Arctic_Ice_Extent","Air_Pollution_Index"]]

# %%
df
# Out:
#            Country  Year  Temperature_Anomaly  CO2_Emissions    Population  \
# 0      Country_103  1913            -1.163537   8.876061e+08  1.627978e+08
# 1      Country_180  1950            -0.432122   4.497517e+08  4.281359e+08
# 2       Country_93  2014             0.444954   4.579080e+08  4.926732e+08
# 3       Country_15  2020            -1.171616   5.049503e+08  1.252169e+09
# 4      Country_107  1964            -0.564038   6.898891e+08  2.932960e+08
# ...            ...   ...                  ...            ...           ...
# 99995  Country_137  1950            -1.375490   4.992342e+08  1.367949e+09
# 99996   Country_42  1921             1.276176   5.846066e+08  1.010792e+09
# 99997   Country_53  1971             1.195518   5.892516e+08  1.466795e+09
# 99998   Country_60  1940            -0.344281   5.008876e+08  4.591192e+07
# 99999  Country_106  1936             0.306962   5.675235e+08  1.088954e+09
#
#        Methane_Emissions  Arctic_Ice_Extent  Air_Pollution_Index
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100000 entries, 0 to 99999
# Data columns (total 8 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   Country              100000 non-null  object
#  1   Year                 100000 non-null  int64
#  2   Temperature_Anomaly  100000 non-null  float64
#  3   CO2_Emissions        100000 non-null  float64
#  4   Population           100000 non-null  float64
#  5   Methane_Emissions    100000 non-null  float64
#  6   Arctic_Ice_Extent    100000 non-null  float64
#  7   Air_Pollution_Index  100000 non-null  float64
# dtypes: float64(6), int64(1), object(1)
# memory usage: 6.1+ MB

# %%
df.describe()
# Out:
#                 Year  Temperature_Anomaly  CO2_Emissions    Population  \
# count  100000.000000        100000.000000   1.000000e+05  1.000000e+05
# mean     1961.422100             0.002647   5.007007e+08  7.501973e+08
# std        35.758799             1.154579   2.887388e+08  4.328709e+08
# min      1900.000000            -1.999981   1.022271e+05  1.013054e+06
# 25%      1930.000000            -0.999449   2.504223e+08  3.762545e+08
# 50%      1961.000000             0.003523   5.006769e+08  7.499212e+08
# 75%      1992.000000             0.998067   7.506318e+08  1.125222e+09
# max      2023.000000             1.999958   9.999793e+08  1.499992e+09
#
#        Methane_Emissions  Arctic_Ice_Extent  Air_Pollution_Index
# count       1.000000e+05      100000.000000        100000.000000
# mean        5.003713e+06           8.003934           149.627677
# std         2.887606e+06           4.039130            86.599662
# min         1.133254e+03           1.000036             0.001419
# ...

# %%
df.shape
# Out:
# (100000, 8)

# %% [markdown]
# <div style="background-color: #aaaaaa; padding: 15px; border-radius: 10px; font-size: 20px; font-weight: 10px">
#   <h1 style="color: #000019; text-align: center; font-family: times new roman;"><strong>CO2_Emissions Data Analysis</strong></h1>
# </div>

# %%
df["CO2_Emissions"]
# Out:
# 0        8.876061e+08
# 1        4.497517e+08
# 2        4.579080e+08
# 3        5.049503e+08
# 4        6.898891e+08
#              ...
# 99995    4.992342e+08
# 99996    5.846066e+08
# 99997    5.892516e+08
# 99998    5.008876e+08
# 99999    5.675235e+08
# Name: CO2_Emissions, Length: 100000, dtype: float64

# %% [markdown]
# <h1 style="color: #36afaa; text-align: left; font-family: times new roman;"><strong>Visualization</strong></h1>

# %%
plt.rcParams['font.family'] = 'Times New Roman'
sns.boxplot(data = df["CO2_Emissions"] , color= "#36afaa")
# Out:
# <Axes: ylabel='CO2_Emissions'>

# %%
# Trend of CO2_Emissions Over Time

plt.figure(figsize=(17, 5))
plt.rcParams['font.family'] = 'Times New Roman'
time_series_var = "CO2_Emissions"
sns.lineplot(data= df, x= "Year", y= time_series_var ,color = "#36afaa")
plt.title(f"Trend of {time_series_var} Over Time")
plt.xlabel("Year")
plt.ylabel(time_series_var)
plt.grid(True)
plt.show()

# %%
# Distribution of CO2_Emissions Over Time

plt.figure(figsize=(14, 4))
plt.rcParams['font.family'] = 'Times New Roman'
sns.histplot(data= df["CO2_Emissions"], kde= True, bins= 30, color= "#36afaa")
plt.title(f"Distribution of CO2_Emissions")
plt.xlabel("CO2_Emissions")
plt.ylabel("Frequency")
plt.show()

# %%
# Distribution of CO2_Emissions Across first 10 Countries

# Filter the dataset for the first 10 countries
first_10_countries = df["Country"].unique()[:10]
filtered_data = df[df["Country"].isin(first_10_countries)]

# Ensure only numeric columns are used for aggregation
numeric_columns = filtered_data.select_dtypes(include=["number"]).columns

# Group by 'Year' and calculate the mean for numeric columns only
yearly_means = filtered_data.groupby(["Year"])[numeric_columns].mean()

variables_to_analyze = ["CO2_Emissions"]

plt.figure(figsize=(10, 4))
plt.rcParams['font.family'] = 'Times New Roman'
for i, var in enumerate(variables_to_analyze, 1):
    plt.subplot(1, len(variables_to_analyze), i)  # adjust based on number of variables
    sns.boxplot(data=filtered_data, x= "Country", y= var, hue= "Country",palette="coolwarm", legend= False )
    plt.title(f"Distribution of {var} Across Countries")
    plt.xlabel("Country")
    plt.ylabel(var)
    plt.xticks(rotation=45)
    plt.grid(axis="y", linestyle="--", alpha=0.7)
plt.tight_layout()
plt.show()

# %% [markdown]
# <div style="background-color: #36afaa; padding: 15px; border-radius: 10px; font-size: 20px; font-weight: 10px">
#   <h1 style="color: #f2f4f4ff; text-align: center; font-family: times new roman;"><strong>Methane_Emissions Data Analysis</strong></h1>
# </div>

# %%
df["Methane_Emissions"]
# Out:
# 0        8.317626e+06
# 1        6.206540e+06
# 2        1.056885e+06
# 3        1.986813e+06
# 4        3.313252e+06
#              ...
# 99995    9.804349e+06
# 99996    3.426378e+05
# 99997    4.429090e+06
# 99998    5.345707e+06
# 99999    6.101980e+06
# Name: Methane_Emissions, Length: 100000, dtype: float64

# %% [markdown]
# <h1 style="color: #36afaa; text-align: left; font-family: times new roman;"><strong>Visualization</strong></h1>

# %%
plt.rcParams['font.family'] = 'Times New Roman'
sns.boxplot(data = df["Methane_Emissions"] , color= "#aaaaaa")
# Out:
# <Axes: ylabel='Methane_Emissions'>

# %%
# Trend of Methane_Emissions Over Time

plt.figure(figsize=(17, 5))
plt.rcParams['font.family'] = 'Times New Roman'
time_series_var = "Methane_Emissions"
sns.lineplot(data= df, x= "Year", y= time_series_var ,color = "#aaaaaa")
plt.title(f"Trend of {time_series_var} Over Time")
plt.xlabel("Year")
plt.ylabel(time_series_var)
plt.grid(True)
plt.show()

# %%
# Distribution of Methane_Emissions Over Time

plt.figure(figsize=(14, 4))
plt.rcParams['font.family'] = 'Times New Roman'
sns.histplot(data= df["Methane_Emissions"], kde= True, bins= 30, color= "#aaaaaa")
plt.title(f"Distribution of Methane_Emissions")
plt.xlabel("Methane_Emissions")
plt.ylabel("Frequency")
plt.show()

# %%
# Distribution of Methane_Emissions Across first 10 Countries

# Filter the dataset for the first 10 countries
first_10_countries = df["Country"].unique()[:10]
filtered_data = df[df["Country"].isin(first_10_countries)]

# Ensure only numeric columns are used for aggregation
numeric_columns = filtered_data.select_dtypes(include=["number"]).columns

# Group by 'Year' and calculate the mean for numeric columns only
yearly_means = filtered_data.groupby(["Year"])[numeric_columns].mean()

variables_to_analyze = ["Methane_Emissions"]

plt.figure(figsize=(10, 4))
plt.rcParams['font.family'] = 'Times New Roman'
for i, var in enumerate(variables_to_analyze, 1):
    plt.subplot(1, len(variables_to_analyze), i)  # adjust based on number of variables
    sns.boxplot(data=filtered_data, x= "Country", y= var, hue= "Country",palette="coolwarm", legend= False )
    plt.title(f"Distribution of {var} Across Countries")
    plt.xlabel("Country")
    plt.ylabel(var)
    plt.xticks(rotation=45)
    plt.grid(axis="y", linestyle="--", alpha=0.7)
plt.tight_layout()
plt.show()

# %% [markdown]
# <div style="background-color: #aaaaaa; padding: 15px; border-radius: 10px; font-size: 20px; font-weight: 10px">
#   <h1 style="color: #000019; text-align: center; font-family: times new roman;"><strong>Arctic_Ice_Extent Data Analysis</strong></h1>
# </div>

# %%
df["Arctic_Ice_Extent"]
# Out:
# 0         7.209066
# 1         8.864252
# 2         8.529665
# 3         5.421442
# 4         4.438027
#            ...
# 99995    13.739067
# 99996     5.607304
# 99997     3.836318
# 99998    13.609246
# 99999     4.465283
# Name: Arctic_Ice_Extent, Length: 100000, dtype: float64

# %% [markdown]
# <h1 style="color: #36afaa; text-align: left; font-family: times new roman;"><strong>Visualization</strong></h1>

# %%
plt.rcParams['font.family'] = 'Times New Roman'
sns.boxplot(data = df["Arctic_Ice_Extent"] , color= "#36afaa")
# Out:
# <Axes: ylabel='Arctic_Ice_Extent'>

# %%
# Trend of Arctic_Ice_Extent Over Time

plt.figure(figsize=(17, 5))
plt.rcParams['font.family'] = 'Times New Roman'
time_series_var = "Arctic_Ice_Extent"
sns.lineplot(data= df, x= "Year", y= time_series_var ,color = "#36afaa")
plt.title(f"Trend of {time_series_var} Over Time")
plt.xlabel("Year")
plt.ylabel(time_series_var)
plt.grid(True)
plt.show()

# %%
# Distribution of Arctic_Ice_Extent Over Time

plt.figure(figsize=(14, 4))
plt.rcParams['font.family'] = 'Times New Roman'
sns.histplot(data= df["Arctic_Ice_Extent"], kde= True, bins= 30, color= "#36afaa")
plt.title(f"Distribution of Arctic_Ice_Extent")
plt.xlabel("Arctic_Ice_Extent")
plt.ylabel("Frequency")
plt.show()

# %%
# Distribution of Arctic_Ice_Extent Across first 10 Countries

# Filter the dataset for the first 10 countries
first_10_countries = df["Country"].unique()[:10]
filtered_data = df[df["Country"].isin(first_10_countries)]

# Ensure only numeric columns are used for aggregation
numeric_columns = filtered_data.select_dtypes(include=["number"]).columns

# Group by 'Year' and calculate the mean for numeric columns only
yearly_means = filtered_data.groupby(["Year"])[numeric_columns].mean()

variables_to_analyze = ["Arctic_Ice_Extent"]

plt.figure(figsize=(10, 4))
plt.rcParams['font.family'] = 'Times New Roman'
for i, var in enumerate(variables_to_analyze, 1):
    plt.subplot(1, len(variables_to_analyze), i)  # adjust based on number of variables
    sns.boxplot(data=filtered_data, x= "Country", y= var, hue= "Country",palette="coolwarm", legend= False )
    plt.title(f"Distribution of {var} Across Countries")
    plt.xlabel("Country")
    plt.ylabel(var)
    plt.xticks(rotation=45)
    plt.grid(axis="y", linestyle="--", alpha=0.7)
plt.tight_layout()
plt.show()

# %% [markdown]
# <div style="background-color: #36afaa; padding: 15px; border-radius: 10px; font-size: 20px; font-weight: 10px">
#   <h1 style="color: #f2f4f4ff; text-align: center; font-family: times new roman;"><strong>Air_Pollution_Index Data Analysis</strong></h1>
# </div>

# %%
df["Air_Pollution_Index"]
# Out:
# 0        150.285539
# 1         27.305922
# 2        216.911429
# 3         35.869182
# 4        284.263093
#             ...
# 99995    169.827985
# 99996    255.464276
# 99997     99.687705
# 99998     35.390332
# 99999     82.452697
# Name: Air_Pollution_Index, Length: 100000, dtype: float64

# %% [markdown]
# <h1 style="color: #36afaa; text-align: left; font-family: times new roman;"><strong>Visualization</strong></h1>

# %%
plt.rcParams['font.family'] = 'Times New Roman'
sns.boxplot(data = df["Air_Pollution_Index"] , color= "#aaaaaa")
# Out:
# <Axes: ylabel='Air_Pollution_Index'>

# %%
# Trend of Air_Pollution_Index Over Time

plt.figure(figsize=(17, 5))
plt.rcParams['font.family'] = 'Times New Roman'
time_series_var = "Air_Pollution_Index"
sns.lineplot(data= df, x= "Year", y= time_series_var ,color = "#aaaaaa")
plt.title(f"Trend of {time_series_var} Over Time")
plt.xlabel("Year")
plt.ylabel(time_series_var)
plt.grid(True)
plt.show()

# %%
# Distribution of Air_Pollution_Index Over Time

plt.figure(figsize=(14, 4))
plt.rcParams['font.family'] = 'Times New Roman'
sns.histplot(data= df["Air_Pollution_Index"], kde= True, bins= 30, color= "#aaaaaa")
plt.title(f"Distribution of Air_Pollution_Index")
plt.xlabel("Air_Pollution_Index")
plt.ylabel("Frequency")
plt.show()

# %%
# Distribution of Air_Pollution_Index Across first 10 Countries

# Filter the dataset for the first 10 countries
first_10_countries = df["Country"].unique()[:10]
filtered_data = df[df["Country"].isin(first_10_countries)]

# Ensure only numeric columns are used for aggregation
numeric_columns = filtered_data.select_dtypes(include=["number"]).columns

# Group by 'Year' and calculate the mean for numeric columns only
yearly_means = filtered_data.groupby(["Year"])[numeric_columns].mean()

variables_to_analyze = ["Air_Pollution_Index"]

plt.figure(figsize=(10, 4))
plt.rcParams['font.family'] = 'Times New Roman'
for i, var in enumerate(variables_to_analyze, 1):
    plt.subplot(1, len(variables_to_analyze), i)  # adjust based on number of variables
    sns.boxplot(data=filtered_data, x= "Country", y= var, hue= "Country",palette="coolwarm", legend= False )
    plt.title(f"Distribution of {var} Across Countries")
    plt.xlabel("Country")
    plt.ylabel(var)
    plt.xticks(rotation=45)
    plt.grid(axis="y", linestyle="--", alpha=0.7)
plt.tight_layout()
plt.show()

# %% [markdown]
# <div style="background-color: #aaaaaa; padding: 15px; border-radius: 10px; font-size: 20px; font-weight: 10px">
#   <h1 style="color: #000019; text-align: center; font-family: times new roman;"><strong>Final Insights</strong></h1>
# </div>

# %% [markdown]
# <div style="font-family: 'Times New Roman'; text-align: left;">
# 1. Large synthetic-like dataset with wide ranges — The variables show broad ranges (CO₂, methane, population, GDP in other columns).The Temperature_Anomaly range (≈ −2 to +2) + the tidy quantiles suggest this dataset is likely synthetic or normalized for demo/education (not raw real-world units).Treat absolute numbers cautiously if you intend to make real-world claims.<br><br>
# 2. CO₂ and methane are large and skewed — Means are high and distributions have long tails (stds are large compared to means).Expect right skew / heavy-tail behavior; boxplots and histograms in the notebook confirm this.<br><br>
# 3. Arctic ice extent distribution — Mean ≈ 8 with wide spread and long tails (min ≈ 1, max ≈ 15).The histograms and time-series plots in the notebook indicate strong temporal behavior — likely a downward long-term trend (the notebook plotted Arctic_Ice_Extent trend).<br><br>
# 4. Air pollution is variable — Mean ≈ 149 but large standard deviation; some countries/years have very low index values while others are very high (up to ≈ 300).Country-level boxplots in the notebook show clear between-country variation.<br><br>
# 5. Temperature anomaly centered near zero — Mean near zero with ±2 range; but the trend matters more than the mean.Notebook contains lineplots for time-series variables (CO₂, methane, Arctic ice, etc.) — these visualizations are the correct approach to detect long-term trends.<br><br>
# 6. Country-level heterogeneity — Boxplots grouped by country (the notebook does this for the first 10 countries) show big between-country differences across variables — good candidate for clustering countries into groups (e.g., high emissions / low emissions / high pollution / low pollution).
# </div><br><br>
#
#
# <div style="font-family: 'Times New Roman'; text-align: left;">
# Limitations & cautions<br><br>
# 1. Likely synthetic / scaled data — some columns (e.g., Temperature_Anomaly bounded at ±2, CO₂ rounded near 1e9) suggest generated values. If your aim is real-world inference, validate and replace with authoritative datasets (e.g., NOAA, CDIAC, GISS, NASA, WMO, EPA).<br><br>
# 2. Units not explicit — many variables lack unit labels in the notebook (e.g., CO₂ units, Arctic ice units). Add explicit units in plots and table captions.<br><br>
# 3. Temporal aggregation and autocorrelation — time-series analysis must account for temporal autocorrelation before doing standard regression or correlation tests.<br><br>
# 4. Missing real-world metadata — country codes, region, income group would help group analysis and policy-relevance.
# </div>
